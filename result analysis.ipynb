# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df_trash = pd.read_csv(filepath_or_buffer=r"D:\graval detection project\mareim runs\train7\results.csv")
df_stone = pd.read_csv(filepath_or_buffer=r"D:\graval detection project\mareim runs\segment\train_UW_1080\results.csv")

# %%
def plot_loss(epochs, loss, loss_type):
    plt.plot(epochs, loss)
    plt.xlabel("epoch")
    plt.ylabel(loss_type)
    plt.title(loss_type)
    plt.grid()
    plt.show()

# %%
plot_loss(epochs=df_trash['                  epoch'], loss=df_trash['         train/seg_loss'],
          loss_type="trash material training seg loss")

# %%
plot_loss(epochs=df_stone['                  epoch'], loss=df_stone['         train/seg_loss'],
          loss_type="stone training seg loss")

# %%
#plot_loss(epochs=df_trash['                  epoch'], loss=df_trash['           val/seg_loss'],
#          loss_type="trash validation seg loss")

# %%
#plot_loss(epochs=df_stone['                  epoch'], loss=df_stone['           val/seg_loss'],
#          loss_type="stone validation seg loss")

# %%
plot_loss(epochs=df_trash['                  epoch'], loss=df_trash['         train/box_loss'],
          loss_type="trash training box loss")

# %%
plot_loss(epochs=df_stone['                  epoch'], loss=df_stone['         train/box_loss'],
          loss_type="stone training box loss")

# %%
#plot_loss(epochs=df_trash['                  epoch'], loss=df_trash['           val/box_loss'],
          #loss_type="trash validation box loss")

# %%
#plot_loss(epochs=df_stone['                  epoch'], loss=df_stone['           val/box_loss'],
          #loss_type="stone validation box loss")

# %%
print(f"trash segmentation train loss: {min(df_trash['         train/seg_loss'])}")
print(f"stone segmenatation train loss: {min(df_stone['         train/seg_loss'])}")
print("================================================================")
print(f"stone segmenation validation loss: {min(df_stone['           val/seg_loss'])}")
print(f"trash segmenation validation loss: {min(df_trash['           val/seg_loss'])}")
print("================================================================")
print(f"trash training BB loss: {min(df_trash['         train/box_loss'])}")
print(f"stone training BB loss: {min(df_stone['         train/box_loss'])}")
print("================================================================")
print(f"stone validation BB loss: {min(df_stone['           val/box_loss'])}")
print(f"trash validation BB loss: {min(df_trash['           val/box_loss'])}")
# Out:
# trash segmentation train loss: 0.97879
# stone segmenatation train loss: 0.66736
# ...
# stone segmenation validation loss: 0.48199
# trash segmenation validation loss: 1.9069
# ...
# trash training BB loss: 0.56897
# stone training BB loss: 0.51699
# ...
# stone validation BB loss: 0.36754
# trash validation BB loss: 1.0808

# %% [markdown]
# Second Test 16/11/2023

# %%
df_trash = pd.read_csv(filepath_or_buffer=r"D:\graval detection project\mareim runs\train9\results.csv")

# %%
plot_loss(epochs=df_trash['                  epoch'], loss=df_trash['         train/seg_loss'],
          loss_type="trash material training seg loss")

# %%
plot_loss(epochs=df_trash['                  epoch'], loss=df_trash['           val/seg_loss'],
          loss_type="trash validation seg loss")

# %% [markdown]
# Third test 11/12/2023

# %%
df_stone = pd.read_csv(filepath_or_buffer=r"D:\graval detection project\mareim runs\train_lastdataset_update_UW\train7\results.csv")

# %%
df_stone.keys()
# Out:
# Index(['                  epoch', '         train/box_loss',
#        '         train/seg_loss', '         train/cls_loss',
#        '         train/dfl_loss', '   metrics/precision(B)',
#        '      metrics/recall(B)', '       metrics/mAP50(B)',
#        '    metrics/mAP50-95(B)', '   metrics/precision(M)',
#        '      metrics/recall(M)', '       metrics/mAP50(M)',
#        '    metrics/mAP50-95(M)', '           val/box_loss',
#        '           val/seg_loss', '           val/cls_loss',
#        '           val/dfl_loss', '                 lr/pg0',
#        '                 lr/pg1', '                 lr/pg2'],
#       dtype='object')

# %%
plot_loss(epochs=df_stone['                  epoch'], loss=df_stone[ '         train/seg_loss'],
          loss_type="stone training seg loss")

# %%
plot_loss(epochs=df_stone['                  epoch'], loss=df_stone[ '         train/box_loss'],
          loss_type="stone training box loss")

# %%
plot_loss(epochs=df_stone['                  epoch'], loss=df_stone['           val/box_loss'],
          loss_type="stone validation box loss")

# %%
plot_loss(epochs=df_stone['                  epoch'], loss=df_stone['           val/seg_loss'],
          loss_type="stone validation seg loss")

# %%
#print(f"trash segmentation train loss: {min(df_trash['         train/seg_loss'])}")
print(f"stone segmenatation train loss: {min(df_stone['         train/seg_loss'])}")
print("================================================================")
print(f"stone segmenation validation loss: {min(df_stone['           val/seg_loss'])}")
#print(f"trash segmenation validation loss: {min(df_trash['           val/seg_loss'])}")
print("================================================================")
#print(f"trash training BB loss: {min(df_trash['         train/box_loss'])}")
print(f"stone training BB loss: {min(df_stone['         train/box_loss'])}")
print("================================================================")
print(f"stone validation BB loss: {min(df_stone['           val/box_loss'])}")
#print(f"trash validation BB loss: {min(df_trash['           val/box_loss'])}")
# Out:
# stone segmenatation train loss: 1.0254
# ...
# stone segmenation validation loss: 0.77612
# ...
# stone training BB loss: 0.85565
# ...
# stone validation BB loss: 0.88824
